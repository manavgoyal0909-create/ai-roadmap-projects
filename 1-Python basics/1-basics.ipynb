# %% [markdown]
# ## basic syntax and sementic rules in python

# %%
## 1)Case sensitivity- Python is case sensitive

name="Manav"
Name="goyal"
print(name)
print(Name)
# Out:
# Manav
# goyal

# %%
## Indentation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required

age=32
if age>30:
    print(age)
# Out:
# 32

# %%
## This is a single line comment 
print("Hello world")
# Out:
# Hello world

# %%
## line continuation
## Use a backslash(\) to continue the statement to the next line

total=1+2+3+4+5+\
4+5+6
print(total)
# Out:
# 30

# %%
## Multiple statements on a single value
x=4;y=7;s=x+y
print(s)
# Out:
# 11

# %%
## Understand semantics in python
# Variabe assignment 
age=32 # age is an integer
name="manav" # here name is a string

# %%
type(age)
# Out:
# int

# %%
## Type inference
variable=10
print(type(variable))
variable="manav"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 ## name error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## Code examples of indentation
if True:
    print("Correct indentation")
    if False:
        print("this will not print")
    print("this will print")
    print("Outside the if block")
# Out:
# Correct indentation
# this will print
# Outside the if block
