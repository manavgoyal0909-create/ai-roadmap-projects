# %% [markdown]
# ## Variables

# %%
## Declaring and Assingning Varibles
age=15
name="manav"
height=5.7


## printing the variables
print("AGE:",age)
print("NAME:",name)
print("HEIGTH:",height)
# Out:
# AGE: 15
# NAME: manav
# HEIGTH: 5.7

# %%
## Naming Convention
## Variables anme should be descriptive
## They must always start with a letter or an underscore(_) and it can contain letters,numbers and underscores 
##  Variables name are case sensitive

## Valid variable names

first_name="Manav"
LAST_NAME="Goyal"

# %%
## invalid variable names

firstname=suii
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 ## invalid variable names
# ----> 3 firstname=suii
#
# NameError: name 'suii' is not defined

# %%
## Case sensitivity

name="Manv"
Name="goyal"

# %%
### Understanding variable types
## Python is dynamically typed,type of a variable is determined at run time
age=23 #int
height=5.7 #float
name="Manav" #str
is_student=True #Bool

# %%
## Type checking and Conversion
type(height)
# Out:
# float

# %%
age=15
print(type(age))

# Type conversion   
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 15
# <class 'str'>

# %%
age=34
print(type(int(age)))
print(type(age))
# Out:
# <class 'int'>
# <class 'int'>

# %%
name="manav"
print(type(int(name)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 name="manav"
# ----> 2 print(type(int(name)))
#
# ValueError: invalid literal for int() with base 10: 'manav'

# %%
## Dynamic Typing
## python allows the type of a variable to change as the program executes
var=20 #int
print(var,type(var))

var="YOOOO"
print(var,type(var))

var=3.4646
print(var,type(var))
# Out:
# 20 <class 'int'>
# YOOOO <class 'str'>
# 3.4646 <class 'float'>

# %%
## Input
age=int(input("What is the age"))
print(age,type(age))
# Out:
# 15 <class 'int'>

# %%
## Simple Calculator
num1=float(input("Enter first number:"))
num2=float(input("Enter second number:"))

sum=num1+num2
difference=num1-num2
product=num1*num2
quotient=num1/num2

print("Sum:",sum)
print("Difference:",difference)
print("product:",product)
print("Quotient:",quotient)
# Out:
# Sum: 6.0
# Difference: 0.0
# product: 9.0
# Quotient: 1.0
