# %% [markdown]
# # Datatypes

# %%
## Integer Example
age=21
type(age)
# Out:
# int

# %%
## Floating type databtype
height=6
print(height)
print(type(height))
# Out:
# 6
# <class 'int'>

# %%
## String datatype example
name="manav" 
print(name)
# Out:
# manav

# %%
## Boolean datatype
True
# Out:
# True

# %%
a=34
b=34
a==b
# Out:
# True

# %%
## Commom errors
result="hello"+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 ## Commom errors
# ----> 2 result="hello"+5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result="hello"+ str(5)
print(result)
# Out:
# hello5
