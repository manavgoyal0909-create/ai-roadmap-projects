# %% [markdown]
# ## Classes and Objects

# %%
## A class is a blueprint for creating objects, attributes and methods

class car:
    pass

audi=car()
bmw=car()

print(type(bmw))
# Out:
# <class '__main__.car'>

# %%
print(audi)
# Out:
# <__main__.car object at 0x000002671B64ACC0>

# %%
audi.windows=4

print(audi.windows)
# Out:
# 4

# %%
tata=car()

tata.doors=4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 tata=car()
#       3 tata.doors=4
# ----> 4 print(tata.windows)
#
# AttributeError: 'car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
## Instance variables and methods

class Dog:
    ## Constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age

## Create objects
dog1=Dog("Johnny",20)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# <__main__.Dog object at 0x000002671D0AF230>
# Johnny
# 20

# %%
dog2=Dog("CR7",22)
print(dog2)
print(dog2.name)
print(dog2.age)
# Out:
# <__main__.Dog object at 0x000002671D286BD0>
# CR7
# 22

# %%
## Define a class with instance methods

class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def bark(self):
        print(f"{self.name} says woof")

dog1=Dog("Ava",19)    
dog1.bark()
dog2=Dog("Alsx",3)
dog2.bark()
# Out:
# Ava says woof
# Alsx says woof

# %%
## Modeling a bank account

# Define a class for bank account

class BankAccount:

    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited .New balance is {self.balance}")

    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient balance")    
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. New balance is {self.balance}")  

    def get_balance(self):
        return self.balance   

## Create an account

account=BankAccount("Batman",100000000)         
print(account.balance)
# Out:
# 100000000

# %%
## Call instance methods

account.deposit(2000000)
account.withdraw(2002000)
# Out:
# 2000000 is deposited .New balance is 104002000
# 2002000 is withdrawn. New balance is 102000000

# %%
account.get_balance()
# Out:
# 102000000
