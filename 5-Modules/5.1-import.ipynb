# %% [markdown]
# ## Importing Modules in python: Modules and packages

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(64))
print(pi)
# Out:
# 8.0
# 3.141592653589793
