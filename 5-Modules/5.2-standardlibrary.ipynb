# %% [markdown]
# ## Standard library overview

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## Random

import random
print(random.randint(1,10))
print(random.choice(['Apple','Banana','Cherry']))
# Out:
# 1
# Apple

# %%
## File and directory access

import os
print(os.getcwd())
# Out:
# c:\Users\DELL\Desktop\ai-roadmap-projects\5-Modules

# %%
os.mkdir('test.dir')

# %%
## High level operations on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data serialization
import json
data={'name':'Manav','age':15}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Manav", "age": 15}
# <class 'str'>
# {'name': 'Manav', 'age': 15}
# <class 'dict'>

# %%
## csv

import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Manav',15])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Manav', '15']

# %%
## Datetime

from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)

print(yesterday)
# Out:
# 2026-04-01 14:53:26.577555
# 2026-03-31 14:53:26.577555

# %%
## Time

import time
print(time.time())
time.sleep(4)
print(time.time())
# Out:
# 1775035517.1634634
# 1775035521.2542686

# %%
## Regular expression

import re

pattern='\d+'
text='There are 123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_200\255164324.py:5: SyntaxWarning: invalid escape sequence '\d'
#   pattern='\d+'
